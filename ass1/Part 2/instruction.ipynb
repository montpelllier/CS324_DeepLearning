# %%
# %run train_mlp_numpy.py
# Out:
# In round 0, the loss is 554.5176018741174, the accuracy is 0.4.
# In round 10, the loss is 554.5150816734908, the accuracy is 0.495.
# In round 20, the loss is 554.5142942976504, the accuracy is 0.495.
# In round 30, the loss is 554.4935528636348, the accuracy is 0.765.
# In round 40, the loss is 554.0076022684609, the accuracy is 0.735.
# In round 50, the loss is 544.9126167465149, the accuracy is 0.735.
# In round 60, the loss is 517.273084899005, the accuracy is 0.735.
# In round 70, the loss is 492.5851251466436, the accuracy is 0.735.
# In round 80, the loss is 472.8748853511423, the accuracy is 0.745.
# In round 90, the loss is 457.1967686659057, the accuracy is 0.755.
# In round 100, the loss is 444.1207839971305, the accuracy is 0.76.
# In round 110, the loss is 433.89635075668684, the accuracy is 0.76.
# In round 120, the loss is 425.4495078966542, the accuracy is 0.765.
# In round 130, the loss is 418.8298681753054, the accuracy is 0.77.
# ...

# %%
# %run train_mlp_numpy.py --sgd True
# Out:
# In round 0, the loss is 0.693154642958592, the accuracy is 0.685.
# In round 10, the loss is 0.6930721493305574, the accuracy is 0.435.
# In round 20, the loss is 0.7136933086522342, the accuracy is 0.435.
# In round 30, the loss is 0.7127664912179348, the accuracy is 0.435.
# In round 40, the loss is 0.711336587551747, the accuracy is 0.435.
# In round 50, the loss is 0.676056919173507, the accuracy is 0.435.
# In round 60, the loss is 0.6765250462023171, the accuracy is 0.435.
# In round 70, the loss is 0.6873523924030774, the accuracy is 0.435.
# In round 80, the loss is 0.7193178760612562, the accuracy is 0.435.
# In round 90, the loss is 0.6976179274105223, the accuracy is 0.435.
# In round 100, the loss is 0.6785014063961254, the accuracy is 0.435.
# In round 110, the loss is 0.6968417318142978, the accuracy is 0.435.
# In round 120, the loss is 0.7071041073633952, the accuracy is 0.435.
# In round 130, the loss is 0.6900944700825822, the accuracy is 0.435.
# ...

# %%
# %run train_mlp_numpy.py --sgd True --max_steps 45000 --eval_freq 500
# Out:
# In round 0, the loss is 0.6931463065355432, the accuracy is 0.75.
# In round 500, the loss is 0.7205616306907293, the accuracy is 0.52.
# In round 1000, the loss is 0.6952218014499377, the accuracy is 0.52.
# In round 1500, the loss is 0.7719304689157566, the accuracy is 0.48.
# In round 2000, the loss is 0.6296773696148162, the accuracy is 0.48.
# In round 2500, the loss is 0.6642769012072309, the accuracy is 0.48.
# In round 3000, the loss is 0.7415273253815854, the accuracy is 0.52.
# In round 3500, the loss is 0.7319975560506965, the accuracy is 0.52.
# In round 4000, the loss is 0.7536269512430138, the accuracy is 0.48.
# In round 4500, the loss is 0.7373458322586155, the accuracy is 0.52.
# In round 5000, the loss is 0.7407483134300106, the accuracy is 0.48.
# In round 5500, the loss is 0.6947775983960289, the accuracy is 0.52.
# In round 6000, the loss is 0.6879688335478751, the accuracy is 0.52.
# In round 6500, the loss is 0.6886538375245351, the accuracy is 0.48.
# ...
