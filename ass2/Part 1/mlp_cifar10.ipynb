# %%
# %run pytorch_train_CIFAR10.py --batch_size 16
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# using GPU Tesla P100-PCIE-16GB
# In round 200, Loss=2.297821521759033, Test Acc=17.8000 %, Train Acc=17.9140 %.
# In round 400, Loss=2.290820837020874, Test Acc=21.7100 %, Train Acc=21.3020 %.
# In round 600, Loss=2.199467182159424, Test Acc=22.1100 %, Train Acc=21.6060 %.
# In round 800, Loss=2.182277202606201, Test Acc=22.9100 %, Train Acc=22.7220 %.
# In round 1000, Loss=2.2014095783233643, Test Acc=26.7600 %, Train Acc=26.5500 %.
# In round 1200, Loss=2.155271291732788, Test Acc=27.9700 %, Train Acc=28.3100 %.
# In round 1400, Loss=2.02480149269104, Test Acc=30.6300 %, Train Acc=30.1200 %.
# In round 1600, Loss=2.2549304962158203, Test Acc=30.7200 %, Train Acc=30.6200 %.
# In round 1800, Loss=2.015836477279663, Test Acc=32.6400 %, Train Acc=32.2900 %.
# In round 2000, Loss=2.169856071472168, Test Acc=34.2600 %, Train Acc=34.4240 %.
# ...

# %%
# %run pytorch_train_CIFAR10.py --batch_size 32 --learning_rate 0.5 --optimizer 2

# %%
# %run pytorch_train_CIFAR10.py --batch_size 32 --learning_rate 0.5 --optimizer 2
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# using GPU Tesla P100-PCIE-16GB
# In round 200, Loss=2.398650884628296, Test Acc=10.2700 %, Train Acc=9.9360 %.
# In round 400, Loss=2.336150884628296, Test Acc=10.2200 %, Train Acc=10.2320 %.
# In round 600, Loss=2.398650884628296, Test Acc=10.3300 %, Train Acc=10.1540 %.
# In round 800, Loss=2.429900884628296, Test Acc=9.7100 %, Train Acc=10.0580 %.
# In round 1000, Loss=2.273650884628296, Test Acc=10.3000 %, Train Acc=10.1220 %.
# In round 1200, Loss=2.398650884628296, Test Acc=10.0200 %, Train Acc=10.1840 %.
# In round 1400, Loss=2.367400884628296, Test Acc=10.2800 %, Train Acc=10.1220 %.
# In round 1600, Loss=2.242400884628296, Test Acc=10.4500 %, Train Acc=10.0120 %.
# In round 1800, Loss=2.367400884628296, Test Acc=9.7800 %, Train Acc=10.0980 %.
# In round 2000, Loss=2.461150884628296, Test Acc=9.9300 %, Train Acc=9.8900 %.
# ...
