# %%
# %run train.py --input_length 5
# Out:
# D:\Software\anaconda3\envs\FL\lib\site-packages\torch\nn\functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# E:\Programme\Python\CS324\ass3\Part 1\lstm.py:56: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   y = functional.softmax(p)
# E:\Programme\Python\CS324\ass3\Part 1\train.py:46: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(model.parameters(), max_norm=config.max_norm)
# Epoch [0/10000], Loss: 2.3517, Accuracy: 9.3750 %.
# Epoch [10/10000], Loss: 2.2725, Accuracy: 17.1875 %.
# Epoch [20/10000], Loss: 2.1499, Accuracy: 31.2500 %.
# Epoch [30/10000], Loss: 2.1386, Accuracy: 32.8125 %.
# Epoch [40/10000], Loss: 2.1260, Accuracy: 33.5938 %.
# ...

# %%
# %run train.py --input_length 10
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "D:\Software\anaconda3\envs\FL\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in safe_execfile
#     py3compat.execfile(
#   File "D:\Software\anaconda3\envs\FL\lib\site-packages\IPython\utils\py3compat.py", line 55, in execfile
#     exec(compiler(f.read(), fname, "exec"), glob, loc)
#   File "E:\Programme\Python\CS324\ass3\Part 1\train.py", line 98, in <module>
#     train(config)
#   File "E:\Programme\Python\CS324\ass3\Part 1\train.py", line 41, in train
#     output = model.forward(batch_inputs)
#   File "E:\Programme\Python\CS324\ass3\Part 1\lstm.py", line 46, in forward
#     i = torch.sigmoid(self.W_ix @ x[:, t].view(1, -1) + self.W_ih @ h_t + self.bias_i)
# NameError: name 'functional' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
# %run train.py --input_length 15
